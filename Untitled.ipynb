# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("merged_dataset.csv")

# %%
data.head(100)
# Out:
#    day,timestamp,product,bid_price_1,bid_volume_1,bid_price_2,bid_volume_2,bid_price_3,bid_volume_3,ask_price_1,ask_volume_1,ask_price_2,ask_volume_2,ask_price_3,ask_volume_3,mid_price,profit_and_loss,buyer,seller,currency,price,quantity
# 0   0,0,ASH_COATED_OSMIUM,,,,,,,10013.0,30.0,,,,,1...
# 1   0,0,INTARIAN_PEPPER_ROOT,11991.0,19.0,,,,,1200...
# 2   0,100,INTARIAN_PEPPER_ROOT,11994.0,9.0,11991.0...
# 3   0,100,ASH_COATED_OSMIUM,9995.0,13.0,,,,,10011....
# 4   0,200,INTARIAN_PEPPER_ROOT,11991.0,20.0,,,,,12...
# ..                                                ...
# 95  0,4700,INTARIAN_PEPPER_ROOT,11998.0,9.0,11995....
# 96  0,4800,INTARIAN_PEPPER_ROOT,11998.0,8.0,11995....
# 97  0,4800,ASH_COATED_OSMIUM,9990.0,24.0,,,,,10009...
# 98  0,4900,ASH_COATED_OSMIUM,9993.0,14.0,9990.0,22...
# 99  0,4900,INTARIAN_PEPPER_ROOT,11998.0,10.0,11995...
#
# [100 rows x 1 columns]
